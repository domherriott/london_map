# %%
import json
import urllib
import pprint
import numpy as np

# %%
geoJson = 'https://raw.githubusercontent.com/oobrien/vis/master/tube/data/tfl_lines.json'
response = urllib.request.urlopen(str(geoJson))
search = json.loads(response.read())
search = search['features']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d4d788c3eda7> in <module>
#       1 geoJson = 'https://raw.githubusercontent.com/oobrien/vis/master/tube/data/tfl_lines.json'
# ----> 2 response = urllib.request.urlopen(str(geoJson))
#       3 search = json.loads(response.read())
#       4 search = search['features']
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#    1390
#    1391             self.sock = self._context.wrap_socket(self.sock,
# -> 1392                                                   server_hostname=server_hostname)
#    1393
#    1394     __all__.append("HTTPSConnection")
#
# ~\AppData\Local\Continuum\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     410             server_hostname=server_hostname,
#     411             context=self,
# --> 412             session=session
#     413         )
#     414
#
# ~\AppData\Local\Continuum\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     851                         # non-blocking
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#     855                 self.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1115             if timeout == 0.0 and block:
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#    1119             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
#Piccadilly line
pic = []

for i in range(41, 92):
    for j in search[i]['geometry']['coordinates']:
        print(i, j[0], j[1])
        pic.append(j)
        
for i in range(95, 97):
    for j in search[i]['geometry']['coordinates']:
        print(i, j[0], j[1])
        pic.append(j)
        
for i in range(420, 430):
    for j in search[i]['geometry']['coordinates']:
        print(i, j[0], j[1])
        pic.append(j)
        
        
for i in range(499, 502):
    for j in search[i]['geometry']['coordinates']:
        print(i, j[0], j[1])
        pic.append(j)


#pic

# %%
url = 'https://raw.githubusercontent.com/domherriott/london_map/master/Data/dStops.json'
response = urllib.request.urlopen(url)
stops = json.loads(response.read())
stops
# Out:
# {'Acton Town Underground Station': {'ID': '940GZZLUACT',
#   'modes': ['tube', 'bus'],
#   'name': 'Acton Town',
#   'lat': 51.503057,
#   'lon': -0.280462,
#   'zone': '3',
#   'lines': ['district', 'piccadilly']},
#  'Aldgate East Underground Station': {'ID': '940GZZLUADE',
#   'modes': ['tube', 'bus'],
#   'name': 'Aldgate East',
#   'lat': 51.515037,
#   'lon': -0.072384,
#   'zone': '1',
#   'lines': ['district', 'hammersmith-city']},
#  'Alperton Underground Station': {'ID': '940GZZLUALP',
#   'modes': ['bus', 'tube'],
#   'name': 'Alperton',
#   'lat': 51.540627,
#   'lon': -0.29961,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Amersham Underground Station': {'ID': 'HUBAMR',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Amersham',
#   'lat': 51.674207,
#   'lon': -0.60759,
#   'zone': '9',
#   'lines': ['metropolitan']},
#  'Angel Underground Station': {'ID': '940GZZLUAGL',
#   'modes': ['bus', 'tube'],
#   'name': 'Angel',
#   'lat': 51.532796,
#   'lon': -0.105992,
#   'zone': '1',
#   'lines': ['northern']},
#  'Archway Underground Station': {'ID': '940GZZLUACY',
#   'modes': ['bus', 'tube'],
#   'name': 'Archway',
#   'lat': 51.565478,
#   'lon': -0.134819,
#   'zone': '2+3',
#   'lines': ['northern']},
#  'Arnos Grove Underground Station': {'ID': '940GZZLUASG',
#   'modes': ['bus', 'tube'],
#   'name': 'Arnos Grove',
#   'lat': 51.616446,
#   'lon': -0.133062,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Baker Street Underground Station': {'ID': '940GZZLUBST',
#   'modes': ['tube', 'bus'],
#   'name': 'Baker Street',
#   'lat': 51.522883,
#   'lon': -0.15713,
#   'zone': '1',
#   'lines': ['bakerloo',
#    'circle',
#    'hammersmith-city',
#    'jubilee',
#    'metropolitan']},
#  'Balham Underground Station': {'ID': 'HUBBAL',
#   'modes': ['national-rail', 'bus', 'tube'],
#   'name': 'Balham',
#   'lat': 51.443259,
#   'lon': -0.152707,
#   'zone': '3',
#   'lines': ['northern']},
#  'Bank Underground Station': {'ID': 'HUBBAN',
#   'modes': ['bus', 'tube', 'dlr'],
#   'name': 'Bank',
#   'lat': 51.513395,
#   'lon': -0.089095,
#   'zone': '1',
#   'lines': ['central', 'northern', 'waterloo-city']},
#  'Barbican Underground Station': {'ID': '940GZZLUBBN',
#   'modes': ['bus', 'tube'],
#   'name': 'Barbican',
#   'lat': 51.520275,
#   'lon': -0.097993,
#   'zone': '1',
#   'lines': ['circle', 'hammersmith-city', 'metropolitan']},
#  'Barking Underground Station': {'ID': 'HUBBKG',
#   'modes': ['bus', 'overground', 'national-rail', 'tube'],
#   'name': 'Barking',
#   'lat': 51.539413,
#   'lon': 0.080988,
#   'zone': '4',
#   'lines': ['district', 'hammersmith-city']},
#  'Barkingside Underground Station': {'ID': '940GZZLUBKE',
#   'modes': ['bus', 'tube'],
#   'name': 'Barkingside',
#   'lat': 51.585689,
#   'lon': 0.088585,
#   'zone': '4',
#   'lines': ['central']},
#  'Barons Court Underground Station': {'ID': '940GZZLUBSC',
#   'modes': ['tube'],
#   'name': 'Barons Court',
#   'lat': 51.490311,
#   'lon': -0.213427,
#   'zone': '2',
#   'lines': ['district', 'piccadilly']},
#  'Bayswater Underground Station': {'ID': '940GZZLUBWT',
#   'modes': ['tube', 'bus'],
#   'name': 'Bayswater',
#   'lat': 51.512284,
#   'lon': -0.187938,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Becontree Underground Station': {'ID': '940GZZLUBEC',
#   'modes': ['bus', 'tube'],
#   'name': 'Becontree',
#   'lat': 51.540331,
#   'lon': 0.127016,
#   'zone': '5',
#   'lines': ['district']},
#  'Belsize Park Underground Station': {'ID': '940GZZLUBZP',
#   'modes': ['bus', 'tube'],
#   'name': 'Belsize Park',
#   'lat': 51.550311,
#   'lon': -0.164648,
#   'zone': '2',
#   'lines': ['northern']},
#  'Bermondsey Underground Station': {'ID': '940GZZLUBMY',
#   'modes': ['bus', 'tube'],
#   'name': 'Bermondsey',
#   'lat': 51.49775,
#   'lon': -0.063993,
#   'zone': '2',
#   'lines': ['jubilee']},
#  'Bethnal Green Underground Station': {'ID': '940GZZLUBLG',
#   'modes': ['bus', 'tube'],
#   'name': 'Bethnal Green',
#   'lat': 51.527222,
#   'lon': -0.055506,
#   'zone': '2',
#   'lines': ['central']},
#  'Blackfriars Underground Station': {'ID': 'HUBBFR',
#   'modes': ['national-rail', 'bus', 'tube'],
#   'name': 'Blackfriars',
#   'lat': 51.509613,
#   'lon': -0.104166,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Blackhorse Road Underground Station': {'ID': 'HUBBHO',
#   'modes': ['tube', 'bus', 'overground'],
#   'name': 'Blackhorse Road',
#   'lat': 51.586768,
#   'lon': -0.041185,
#   'zone': '3',
#   'lines': ['victoria']},
#  'Bond Street Underground Station': {'ID': '940GZZLUBND',
#   'modes': ['tube', 'bus'],
#   'name': 'Bond Street',
#   'lat': 51.514304,
#   'lon': -0.149723,
#   'zone': '1',
#   'lines': ['central', 'jubilee']},
#  'Borough Underground Station': {'ID': '940GZZLUBOR',
#   'modes': ['tube', 'bus'],
#   'name': 'Borough',
#   'lat': 51.501199,
#   'lon': -0.09337,
#   'zone': '1',
#   'lines': ['northern']},
#  'Boston Manor Underground Station': {'ID': '940GZZLUBOS',
#   'modes': ['bus', 'tube'],
#   'name': 'Boston Manor',
#   'lat': 51.495635,
#   'lon': -0.324939,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Bounds Green Underground Station': {'ID': '940GZZLUBDS',
#   'modes': ['bus', 'tube'],
#   'name': 'Bounds Green',
#   'lat': 51.607034,
#   'lon': -0.124235,
#   'zone': '3+4',
#   'lines': ['piccadilly']},
#  'Bow Road Underground Station': {'ID': '940GZZLUBWR',
#   'modes': ['bus', 'tube'],
#   'name': 'Bow Road',
#   'lat': 51.52694,
#   'lon': -0.025128,
#   'zone': '2',
#   'lines': ['district', 'hammersmith-city']},
#  'Brent Cross Underground Station': {'ID': '940GZZLUBTX',
#   'modes': ['tube', 'bus'],
#   'name': 'Brent Cross',
#   'lat': 51.57665,
#   'lon': -0.213622,
#   'zone': '3',
#   'lines': ['northern']},
#  'Brixton Underground Station': {'ID': 'HUBBRX',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Brixton',
#   'lat': 51.462961,
#   'lon': -0.114531,
#   'zone': '2',
#   'lines': ['victoria']},
#  'Bromley-by-Bow Underground Station': {'ID': '940GZZLUBBB',
#   'modes': ['bus', 'tube'],
#   'name': 'Bromley-by-Bow',
#   'lat': 51.524839,
#   'lon': -0.011538,
#   'zone': '2+3',
#   'lines': ['district', 'hammersmith-city']},
#  'Buckhurst Hill Underground Station': {'ID': '940GZZLUBKH',
#   'modes': ['tube', 'bus'],
#   'name': 'Buckhurst Hill',
#   'lat': 51.626605,
#   'lon': 0.046757,
#   'zone': '5',
#   'lines': ['central']},
#  'Burnt Oak Underground Station': {'ID': '940GZZLUBTK',
#   'modes': ['bus', 'tube'],
#   'name': 'Burnt Oak',
#   'lat': 51.602774,
#   'lon': -0.264048,
#   'zone': '4',
#   'lines': ['northern']},
#  'Camden Town Underground Station': {'ID': '940GZZLUCTN',
#   'modes': ['bus', 'tube'],
#   'name': 'Camden Town',
#   'lat': 51.539292,
#   'lon': -0.14274,
#   'zone': '2',
#   'lines': ['northern']},
#  'Canada Water Underground Station': {'ID': 'HUBZCW',
#   'modes': ['bus', 'overground', 'tube'],
#   'name': 'Canada Water',
#   'lat': 51.498053,
#   'lon': -0.049667,
#   'zone': '2',
#   'lines': ['jubilee']},
#  'Canary Wharf Underground Station': {'ID': 'HUBCAW',
#   'modes': ['tube', 'dlr', 'bus'],
#   'name': 'Canary Wharf',
#   'lat': 51.503734,
#   'lon': -0.019121,
#   'zone': '2',
#   'lines': ['jubilee']},
#  'Canning Town Underground Station': {'ID': 'HUBCAN',
#   'modes': ['dlr', 'bus', 'tube'],
#   'name': 'Canning Town',
#   'lat': 51.514029,
#   'lon': 0.008025,
#   'zone': '2/3',
#   'lines': ['jubilee']},
#  'Cannon Street Underground Station': {'ID': 'HUBCST',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Cannon Street',
#   'lat': 51.511451,
#   'lon': -0.090357,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Canons Park Underground Station': {'ID': '940GZZLUCPK',
#   'modes': ['bus', 'tube'],
#   'name': 'Canons Park',
#   'lat': 51.607701,
#   'lon': -0.294693,
#   'zone': '5',
#   'lines': ['jubilee']},
#  'Chalfont & Latimer Underground Station': {'ID': 'HUBCFO',
#   'modes': ['bus', 'tube', 'national-rail'],
#   'name': 'Chalfont & Latimer',
#   'lat': 51.668109,
#   'lon': -0.560519,
#   'zone': '8',
#   'lines': ['metropolitan']},
#  'Chalk Farm Underground Station': {'ID': '940GZZLUCFM',
#   'modes': ['bus', 'tube'],
#   'name': 'Chalk Farm',
#   'lat': 51.544118,
#   'lon': -0.153388,
#   'zone': '2',
#   'lines': ['northern']},
#  'Chancery Lane Underground Station': {'ID': '940GZZLUCHL',
#   'modes': ['tube', 'bus'],
#   'name': 'Chancery Lane',
#   'lat': 51.518247,
#   'lon': -0.111583,
#   'zone': '1',
#   'lines': ['central']},
#  'Charing Cross Underground Station': {'ID': 'HUBCHX',
#   'modes': ['tube', 'national-rail', 'bus'],
#   'name': 'Charing Cross',
#   'lat': 51.507819,
#   'lon': -0.126137,
#   'zone': '1',
#   'lines': ['bakerloo', 'northern']},
#  'Chesham Underground Station': {'ID': '940GZZLUCSM',
#   'modes': ['tube'],
#   'name': 'Chesham',
#   'lat': 51.705208,
#   'lon': -0.611247,
#   'zone': '9',
#   'lines': ['metropolitan']},
#  'Chigwell Underground Station': {'ID': '940GZZLUCWL',
#   'modes': ['tube', 'bus'],
#   'name': 'Chigwell',
#   'lat': 51.617916,
#   'lon': 0.075041,
#   'zone': '4',
#   'lines': ['central']},
#  'Chiswick Park Underground Station': {'ID': '940GZZLUCWP',
#   'modes': ['tube'],
#   'name': 'Chiswick Park',
#   'lat': 51.494627,
#   'lon': -0.267972,
#   'zone': '3',
#   'lines': ['district']},
#  'Chorleywood Underground Station': {'ID': 'HUBCLW',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Chorleywood',
#   'lat': 51.654249,
#   'lon': -0.518312,
#   'zone': '7',
#   'lines': ['metropolitan']},
#  'Clapham Common Underground Station': {'ID': '940GZZLUCPC',
#   'modes': ['bus', 'tube'],
#   'name': 'Clapham Common',
#   'lat': 51.461742,
#   'lon': -0.138317,
#   'zone': '2',
#   'lines': ['northern']},
#  'Clapham North Underground Station': {'ID': '940GZZLUCPN',
#   'modes': ['tube', 'bus'],
#   'name': 'Clapham North',
#   'lat': 51.465135,
#   'lon': -0.130016,
#   'zone': '2',
#   'lines': ['northern']},
#  'Clapham South Underground Station': {'ID': '940GZZLUCPS',
#   'modes': ['tube', 'bus'],
#   'name': 'Clapham South',
#   'lat': 51.452654,
#   'lon': -0.147582,
#   'zone': '2+3',
#   'lines': ['northern']},
#  'Cockfosters Underground Station': {'ID': '940GZZLUCKS',
#   'modes': ['tube', 'bus'],
#   'name': 'Cockfosters',
#   'lat': 51.65152,
#   'lon': -0.149171,
#   'zone': '5',
#   'lines': ['piccadilly']},
#  'Colindale Underground Station': {'ID': '940GZZLUCND',
#   'modes': ['bus', 'tube'],
#   'name': 'Colindale',
#   'lat': 51.595424,
#   'lon': -0.249919,
#   'zone': '4',
#   'lines': ['northern']},
#  'Colliers Wood Underground Station': {'ID': '940GZZLUCSD',
#   'modes': ['tube', 'bus'],
#   'name': 'Colliers Wood',
#   'lat': 51.41816,
#   'lon': -0.178086,
#   'zone': '3',
#   'lines': ['northern']},
#  'Covent Garden Underground Station': {'ID': '940GZZLUCGN',
#   'modes': ['tube'],
#   'name': 'Covent Garden',
#   'lat': 51.513093,
#   'lon': -0.124436,
#   'zone': '1',
#   'lines': ['piccadilly']},
#  'Croxley Underground Station': {'ID': '940GZZLUCXY',
#   'modes': ['tube'],
#   'name': 'Croxley',
#   'lat': 51.647044,
#   'lon': -0.441718,
#   'zone': '7',
#   'lines': ['metropolitan']},
#  'Dagenham East Underground Station': {'ID': '940GZZLUDGE',
#   'modes': ['tube', 'bus'],
#   'name': 'Dagenham East',
#   'lat': 51.544096,
#   'lon': 0.166017,
#   'zone': '5',
#   'lines': ['district']},
#  'Dagenham Heathway Underground Station': {'ID': '940GZZLUDGY',
#   'modes': ['tube', 'bus'],
#   'name': 'Dagenham Heathway',
#   'lat': 51.541639,
#   'lon': 0.147527,
#   'zone': '5',
#   'lines': ['district']},
#  'Debden Underground Station': {'ID': '940GZZLUDBN',
#   'modes': ['tube'],
#   'name': 'Debden',
#   'lat': 51.645386,
#   'lon': 0.083782,
#   'zone': '6',
#   'lines': ['central']},
#  'Dollis Hill Underground Station': {'ID': '940GZZLUDOH',
#   'modes': ['bus', 'tube'],
#   'name': 'Dollis Hill',
#   'lat': 51.551955,
#   'lon': -0.239068,
#   'zone': '3',
#   'lines': ['jubilee']},
#  'Ealing Broadway Underground Station': {'ID': 'HUBEAL',
#   'modes': ['tflrail', 'bus', 'national-rail', 'tube'],
#   'name': 'Ealing Broadway',
#   'lat': 51.514993,
#   'lon': -0.302131,
#   'zone': '3',
#   'lines': ['central', 'district']},
#  'Ealing Common Underground Station': {'ID': '940GZZLUECM',
#   'modes': ['bus', 'tube'],
#   'name': 'Ealing Common',
#   'lat': 51.51014,
#   'lon': -0.288265,
#   'zone': '3',
#   'lines': ['district', 'piccadilly']},
#  "Earl's Court Underground Station": {'ID': '940GZZLUECT',
#   'modes': ['bus', 'tube'],
#   'name': "Earl's Court",
#   'lat': 51.492063,
#   'lon': -0.193378,
#   'zone': '1+2',
#   'lines': ['district', 'piccadilly']},
#  'East Acton Underground Station': {'ID': '940GZZLUEAN',
#   'modes': ['bus', 'tube'],
#   'name': 'East Acton',
#   'lat': 51.516612,
#   'lon': -0.247248,
#   'zone': '2',
#   'lines': ['central']},
#  'East Finchley Underground Station': {'ID': '940GZZLUEFY',
#   'modes': ['tube', 'bus'],
#   'name': 'East Finchley',
#   'lat': 51.587131,
#   'lon': -0.165012,
#   'zone': '3',
#   'lines': ['northern']},
#  'East Ham Underground Station': {'ID': '940GZZLUEHM',
#   'modes': ['bus', 'tube'],
#   'name': 'East Ham',
#   'lat': 51.538948,
#   'lon': 0.051186,
#   'zone': '3+4',
#   'lines': ['district', 'hammersmith-city']},
#  'East Putney Underground Station': {'ID': '940GZZLUEPY',
#   'modes': ['bus', 'tube'],
#   'name': 'East Putney',
#   'lat': 51.459205,
#   'lon': -0.211,
#   'zone': '2+3',
#   'lines': ['district']},
#  'Eastcote Underground Station': {'ID': '940GZZLUEAE',
#   'modes': ['bus', 'tube'],
#   'name': 'Eastcote',
#   'lat': 51.576506,
#   'lon': -0.397373,
#   'zone': '5',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Edgware Underground Station': {'ID': '940GZZLUEGW',
#   'modes': ['tube', 'bus'],
#   'name': 'Edgware',
#   'lat': 51.613653,
#   'lon': -0.274928,
#   'zone': '5',
#   'lines': ['northern']},
#  'Edgware Road (Bakerloo) Underground Station': {'ID': '940GZZLUERB',
#   'modes': ['tube', 'bus'],
#   'name': 'Edgware Road',
#   'lat': 51.520299,
#   'lon': -0.17015,
#   'zone': '1',
#   'lines': ['bakerloo']},
#  'Elephant & Castle Underground Station': {'ID': 'HUBEPH',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Elephant & Castle',
#   'lat': 51.494505,
#   'lon': -0.099185,
#   'zone': '1+2',
#   'lines': ['bakerloo', 'northern']},
#  'Elm Park Underground Station': {'ID': '940GZZLUEPK',
#   'modes': ['bus', 'tube'],
#   'name': 'Elm Park',
#   'lat': 51.549775,
#   'lon': 0.19864,
#   'zone': '6',
#   'lines': ['district']},
#  'Epping Underground Station': {'ID': '940GZZLUEPG',
#   'modes': ['tube'],
#   'name': 'Epping',
#   'lat': 51.69368,
#   'lon': 0.113767,
#   'zone': '6',
#   'lines': ['central']},
#  'Euston Underground Station': {'ID': 'HUBEUS',
#   'modes': ['overground', 'tube', 'bus', 'national-rail'],
#   'name': 'Euston',
#   'lat': 51.527365,
#   'lon': -0.132754,
#   'zone': '1',
#   'lines': ['northern', 'victoria']},
#  'Euston Square Underground Station': {'ID': '940GZZLUESQ',
#   'modes': ['bus', 'tube'],
#   'name': 'Euston Square',
#   'lat': 51.525604,
#   'lon': -0.135829,
#   'zone': '1',
#   'lines': ['circle', 'hammersmith-city', 'metropolitan']},
#  'Fairlop Underground Station': {'ID': '940GZZLUFLP',
#   'modes': ['bus', 'tube'],
#   'name': 'Fairlop',
#   'lat': 51.595618,
#   'lon': 0.091004,
#   'zone': '4',
#   'lines': ['central']},
#  'Farringdon Underground Station': {'ID': 'HUBZFD',
#   'modes': ['national-rail', 'bus', 'tube'],
#   'name': 'Farringdon',
#   'lat': 51.520214,
#   'lon': -0.105054,
#   'zone': '1',
#   'lines': ['circle', 'hammersmith-city', 'metropolitan']},
#  'Finchley Central Underground Station': {'ID': '940GZZLUFYC',
#   'modes': ['bus', 'tube'],
#   'name': 'Finchley Central',
#   'lat': 51.600921,
#   'lon': -0.192527,
#   'zone': '4',
#   'lines': ['northern']},
#  'Finsbury Park Underground Station': {'ID': 'HUBFPK',
#   'modes': ['bus', 'tube', 'national-rail'],
#   'name': 'Finsbury Park',
#   'lat': 51.564778,
#   'lon': -0.105876,
#   'zone': '2',
#   'lines': ['piccadilly', 'victoria']},
#  'Fulham Broadway Underground Station': {'ID': '940GZZLUFBY',
#   'modes': ['tube', 'bus'],
#   'name': 'Fulham Broadway',
#   'lat': 51.480081,
#   'lon': -0.195422,
#   'zone': '2',
#   'lines': ['district']},
#  'Gants Hill Underground Station': {'ID': '940GZZLUGTH',
#   'modes': ['bus', 'tube'],
#   'name': 'Gants Hill',
#   'lat': 51.576544,
#   'lon': 0.066185,
#   'zone': '4',
#   'lines': ['central']},
#  'Gloucester Road Underground Station': {'ID': '940GZZLUGTR',
#   'modes': ['tube', 'bus'],
#   'name': 'Gloucester Road',
#   'lat': 51.494316,
#   'lon': -0.182658,
#   'zone': '1',
#   'lines': ['circle', 'district', 'piccadilly']},
#  'Golders Green Underground Station': {'ID': '940GZZLUGGN',
#   'modes': ['tube', 'bus'],
#   'name': 'Golders Green',
#   'lat': 51.572259,
#   'lon': -0.194039,
#   'zone': '3',
#   'lines': ['northern']},
#  'Goldhawk Road Underground Station': {'ID': '940GZZLUGHK',
#   'modes': ['bus', 'tube'],
#   'name': 'Goldhawk Road',
#   'lat': 51.502005,
#   'lon': -0.226715,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Goodge Street Underground Station': {'ID': '940GZZLUGDG',
#   'modes': ['tube', 'bus'],
#   'name': 'Goodge Street',
#   'lat': 51.520599,
#   'lon': -0.134361,
#   'zone': '1',
#   'lines': ['northern']},
#  'Grange Hill Underground Station': {'ID': '940GZZLUGGH',
#   'modes': ['tube', 'bus'],
#   'name': 'Grange Hill',
#   'lat': 51.613378,
#   'lon': 0.092066,
#   'zone': '4',
#   'lines': ['central']},
#  'Great Portland Street Underground Station': {'ID': '940GZZLUGPS',
#   'modes': ['tube', 'bus'],
#   'name': 'Great Portland Street',
#   'lat': 51.52384,
#   'lon': -0.144262,
#   'zone': '1',
#   'lines': ['circle', 'hammersmith-city', 'metropolitan']},
#  'Green Park Underground Station': {'ID': '940GZZLUGPK',
#   'modes': ['bus', 'tube'],
#   'name': 'Green Park',
#   'lat': 51.506947,
#   'lon': -0.142787,
#   'zone': '1',
#   'lines': ['jubilee', 'piccadilly', 'victoria']},
#  'Greenford Underground Station': {'ID': 'HUBGFD',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Greenford',
#   'lat': 51.542657,
#   'lon': -0.345789,
#   'zone': '4',
#   'lines': ['central']},
#  'North Greenwich Underground Station': {'ID': 'HUBNGW',
#   'modes': ['cable-car', 'tube', 'bus'],
#   'name': 'North Greenwich',
#   'lat': 51.500474,
#   'lon': 0.004295,
#   'zone': '2+3',
#   'lines': ['jubilee']},
#  'Gunnersbury Underground Station': {'ID': 'HUBGUN',
#   'modes': ['tube', 'bus', 'overground'],
#   'name': 'Gunnersbury',
#   'lat': 51.491745,
#   'lon': -0.275276,
#   'zone': '3',
#   'lines': ['district']},
#  'Hainault Underground Station': {'ID': '940GZZLUHLT',
#   'modes': ['bus', 'tube'],
#   'name': 'Hainault',
#   'lat': 51.603659,
#   'lon': 0.093482,
#   'zone': '4',
#   'lines': ['central']},
#  'Hammersmith Underground Station': {'ID': 'HUBHMS',
#   'modes': ['bus', 'tube'],
#   'name': 'Hammersmith',
#   'lat': 51.492304,
#   'lon': -0.223619,
#   'zone': '2',
#   'lines': []},
#  'West Hampstead Underground Station': {'ID': 'HUBWHD',
#   'modes': ['national-rail', 'bus', 'overground', 'tube'],
#   'name': 'West Hampstead',
#   'lat': 51.547533,
#   'lon': -0.191357,
#   'zone': '2',
#   'lines': ['jubilee']},
#  'Hanger Lane Underground Station': {'ID': '940GZZLUHGR',
#   'modes': ['bus', 'tube'],
#   'name': 'Hanger Lane',
#   'lat': 51.530177,
#   'lon': -0.292704,
#   'zone': '3',
#   'lines': ['central']},
#  'Harlesden Underground Station': {'ID': 'HUBHDN',
#   'modes': ['tube', 'bus', 'overground'],
#   'name': 'Harlesden',
#   'lat': 51.536305,
#   'lon': -0.257774,
#   'zone': '3',
#   'lines': ['bakerloo']},
#  'Harrow & Wealdstone Underground Station': {'ID': 'HUBHRW',
#   'modes': ['national-rail', 'bus', 'overground', 'tube'],
#   'name': 'Harrow & Wealdstone',
#   'lat': 51.592216,
#   'lon': -0.334896,
#   'zone': '5',
#   'lines': ['bakerloo']},
#  'Harrow-on-the-Hill Underground Station': {'ID': 'HUBHOH',
#   'modes': ['national-rail', 'bus', 'tube'],
#   'name': 'Harrow-on-the-Hill',
#   'lat': 51.579197,
#   'lon': -0.337226,
#   'zone': '5',
#   'lines': ['metropolitan']},
#  'Hatton Cross Underground Station': {'ID': '940GZZLUHNX',
#   'modes': ['bus', 'tube'],
#   'name': 'Hatton Cross',
#   'lat': 51.466747,
#   'lon': -0.423191,
#   'zone': '5+6',
#   'lines': ['piccadilly']},
#  'Heathrow Terminals 1-2-3 Underground Station': {'ID': '9400ZZLUHRC2',
#   'modes': ['tube'],
#   'name': 'Heathrow Terminals 1-2-3 Underground Station',
#   'lat': 51.471352,
#   'lon': -0.45229,
#   'zone': '6',
#   'lines': []},
#  'Hendon Central Underground Station': {'ID': '940GZZLUHCL',
#   'modes': ['bus', 'tube'],
#   'name': 'Hendon Central',
#   'lat': 51.583301,
#   'lon': -0.226424,
#   'zone': '3+4',
#   'lines': ['northern']},
#  'High Barnet Underground Station': {'ID': '940GZZLUHBT',
#   'modes': ['bus', 'tube'],
#   'name': 'High Barnet',
#   'lat': 51.650541,
#   'lon': -0.194298,
#   'zone': '5',
#   'lines': ['northern']},
#  'High Street Kensington Underground Station': {'ID': '940GZZLUHSK',
#   'modes': ['bus', 'tube'],
#   'name': 'High Street Kensington',
#   'lat': 51.501055,
#   'lon': -0.192792,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Highbury & Islington Underground Station': {'ID': 'HUBHHY',
#   'modes': ['overground', 'bus', 'tube', 'national-rail'],
#   'name': 'Highbury & Islington',
#   'lat': 51.546269,
#   'lon': -0.103538,
#   'zone': '2',
#   'lines': ['victoria']},
#  'Highgate Underground Station': {'ID': '940GZZLUHGT',
#   'modes': ['bus', 'tube'],
#   'name': 'Highgate',
#   'lat': 51.577532,
#   'lon': -0.145857,
#   'zone': '3',
#   'lines': ['northern']},
#  'Hillingdon Underground Station': {'ID': '940GZZLUHGD',
#   'modes': ['bus', 'tube'],
#   'name': 'Hillingdon',
#   'lat': 51.553715,
#   'lon': -0.449828,
#   'zone': '6',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Holborn Underground Station': {'ID': '940GZZLUHBN',
#   'modes': ['tube', 'bus'],
#   'name': 'Holborn',
#   'lat': 51.51758,
#   'lon': -0.120475,
#   'zone': '1',
#   'lines': ['central', 'piccadilly']},
#  'Holland Park Underground Station': {'ID': '940GZZLUHPK',
#   'modes': ['tube', 'bus'],
#   'name': 'Holland Park',
#   'lat': 51.507143,
#   'lon': -0.205679,
#   'zone': '2',
#   'lines': ['central']},
#  'Holloway Road Underground Station': {'ID': '940GZZLUHWY',
#   'modes': ['bus', 'tube'],
#   'name': 'Holloway Road',
#   'lat': 51.552697,
#   'lon': -0.113244,
#   'zone': '2',
#   'lines': ['piccadilly']},
#  'Hornchurch Underground Station': {'ID': '940GZZLUHCH',
#   'modes': ['tube', 'bus'],
#   'name': 'Hornchurch',
#   'lat': 51.554093,
#   'lon': 0.219116,
#   'zone': '6',
#   'lines': ['district']},
#  'Hounslow Central Underground Station': {'ID': '940GZZLUHWC',
#   'modes': ['bus', 'tube'],
#   'name': 'Hounslow Central',
#   'lat': 51.471295,
#   'lon': -0.366578,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Hounslow East Underground Station': {'ID': '940GZZLUHWE',
#   'modes': ['tube', 'bus'],
#   'name': 'Hounslow East',
#   'lat': 51.473213,
#   'lon': -0.356474,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Hounslow West Underground Station': {'ID': '940GZZLUHWT',
#   'modes': ['bus', 'tube'],
#   'name': 'Hounslow West',
#   'lat': 51.473469,
#   'lon': -0.386544,
#   'zone': '5',
#   'lines': ['piccadilly']},
#  'Hyde Park Corner Underground Station': {'ID': '940GZZLUHPC',
#   'modes': ['bus', 'tube'],
#   'name': 'Hyde Park Corner',
#   'lat': 51.503035,
#   'lon': -0.152441,
#   'zone': '1',
#   'lines': ['piccadilly']},
#  'Ickenham Underground Station': {'ID': '940GZZLUICK',
#   'modes': ['tube', 'bus'],
#   'name': 'Ickenham',
#   'lat': 51.561992,
#   'lon': -0.442001,
#   'zone': '6',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Kennington Underground Station': {'ID': '940GZZLUKNG',
#   'modes': ['tube', 'bus'],
#   'name': 'Kennington',
#   'lat': 51.488337,
#   'lon': -0.105963,
#   'zone': '2',
#   'lines': ['northern']},
#  'Kensal Green Underground Station': {'ID': 'HUBKNL',
#   'modes': ['overground', 'bus', 'tube'],
#   'name': 'Kensal Green',
#   'lat': 51.530545,
#   'lon': -0.22505,
#   'zone': '2',
#   'lines': ['bakerloo']},
#  'Kensington (Olympia) Underground Station': {'ID': 'HUBKPA',
#   'modes': ['bus', 'overground', 'national-rail', 'tube'],
#   'name': 'Kensington (Olympia)',
#   'lat': 51.496156,
#   'lon': -0.210502,
#   'zone': '2',
#   'lines': ['district']},
#  'Kentish Town Underground Station': {'ID': 'HUBKTN',
#   'modes': ['bus', 'tube', 'national-rail'],
#   'name': 'Kentish Town',
#   'lat': 51.550409,
#   'lon': -0.140545,
#   'zone': '2',
#   'lines': ['northern']},
#  'Kenton Underground Station': {'ID': 'HUBKNT',
#   'modes': ['overground', 'bus', 'tube'],
#   'name': 'Kenton',
#   'lat': 51.581786,
#   'lon': -0.316946,
#   'zone': '4',
#   'lines': ['bakerloo']},
#  'Kew Gardens Underground Station': {'ID': 'HUBKWG',
#   'modes': ['bus', 'overground', 'tube'],
#   'name': 'Kew Gardens',
#   'lat': 51.477069,
#   'lon': -0.285148,
#   'zone': '3+4',
#   'lines': ['district']},
#  'Kilburn Park Underground Station': {'ID': '940GZZLUKPK',
#   'modes': ['bus', 'tube'],
#   'name': 'Kilburn Park',
#   'lat': 51.534979,
#   'lon': -0.194232,
#   'zone': '2',
#   'lines': ['bakerloo']},
#  'Kingsbury Underground Station': {'ID': '940GZZLUKBY',
#   'modes': ['bus', 'tube'],
#   'name': 'Kingsbury',
#   'lat': 51.584845,
#   'lon': -0.27879,
#   'zone': '4',
#   'lines': ['jubilee']},
#  'Knightsbridge Underground Station': {'ID': '940GZZLUKNB',
#   'modes': ['bus', 'tube'],
#   'name': 'Knightsbridge',
#   'lat': 51.501669,
#   'lon': -0.160508,
#   'zone': '1',
#   'lines': ['piccadilly']},
#  'Ladbroke Grove Underground Station': {'ID': '940GZZLULAD',
#   'modes': ['tube', 'bus'],
#   'name': 'Ladbroke Grove',
#   'lat': 51.517449,
#   'lon': -0.210391,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Lambeth North Underground Station': {'ID': '940GZZLULBN',
#   'modes': ['tube', 'bus'],
#   'name': 'Lambeth North',
#   'lat': 51.498808,
#   'lon': -0.112315,
#   'zone': '1',
#   'lines': ['bakerloo']},
#  'Latimer Road Underground Station': {'ID': '940GZZLULRD',
#   'modes': ['tube', 'bus'],
#   'name': 'Latimer Road',
#   'lat': 51.513389,
#   'lon': -0.217799,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Leicester Square Underground Station': {'ID': '940GZZLULSQ',
#   'modes': ['tube', 'bus'],
#   'name': 'Leicester Square',
#   'lat': 51.511386,
#   'lon': -0.128426,
#   'zone': '1',
#   'lines': ['northern', 'piccadilly']},
#  'Liverpool Street Underground Station': {'ID': 'HUBLST',
#   'modes': ['tube', 'tflrail', 'national-rail', 'bus', 'overground'],
#   'name': 'Liverpool Street',
#   'lat': 51.51794,
#   'lon': -0.083162,
#   'zone': '1',
#   'lines': ['central', 'circle', 'hammersmith-city', 'metropolitan']},
#  'London Bridge Underground Station': {'ID': 'HUBLBG',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'London Bridge',
#   'lat': 51.505881,
#   'lon': -0.086807,
#   'zone': '1',
#   'lines': ['jubilee', 'northern']},
#  'Loughton Underground Station': {'ID': '940GZZLULGN',
#   'modes': ['tube'],
#   'name': 'Loughton',
#   'lat': 51.641443,
#   'lon': 0.055476,
#   'zone': '6',
#   'lines': ['central']},
#  'Maida Vale Underground Station': {'ID': '940GZZLUMVL',
#   'modes': ['tube'],
#   'name': 'Maida Vale',
#   'lat': 51.529777,
#   'lon': -0.185758,
#   'zone': '2',
#   'lines': ['bakerloo']},
#  'Manor House Underground Station': {'ID': '940GZZLUMRH',
#   'modes': ['bus', 'tube'],
#   'name': 'Manor House',
#   'lat': 51.570738,
#   'lon': -0.096118,
#   'zone': '2+3',
#   'lines': ['piccadilly']},
#  'Mansion House Underground Station': {'ID': '940GZZLUMSH',
#   'modes': ['tube', 'bus'],
#   'name': 'Mansion House',
#   'lat': 51.512117,
#   'lon': -0.094009,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Marble Arch Underground Station': {'ID': '940GZZLUMBA',
#   'modes': ['tube', 'bus'],
#   'name': 'Marble Arch',
#   'lat': 51.513424,
#   'lon': -0.158953,
#   'zone': '1',
#   'lines': ['central']},
#  'Marylebone Underground Station': {'ID': 'HUBMYB',
#   'modes': ['tube', 'national-rail', 'bus'],
#   'name': 'Marylebone',
#   'lat': 51.521602,
#   'lon': -0.163013,
#   'zone': '1',
#   'lines': ['bakerloo']},
#  'Mile End Underground Station': {'ID': '940GZZLUMED',
#   'modes': ['tube', 'bus'],
#   'name': 'Mile End',
#   'lat': 51.525122,
#   'lon': -0.03364,
#   'zone': '2',
#   'lines': ['central', 'district', 'hammersmith-city']},
#  'Mill Hill East Underground Station': {'ID': '940GZZLUMHL',
#   'modes': ['bus', 'tube'],
#   'name': 'Mill Hill East',
#   'lat': 51.608229,
#   'lon': -0.209986,
#   'zone': '4',
#   'lines': ['northern']},
#  'Monument Underground Station': {'ID': '940GZZLUMMT',
#   'modes': ['bus', 'tube'],
#   'name': 'Monument',
#   'lat': 51.5107,
#   'lon': -0.085969,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Moor Park Underground Station': {'ID': '940GZZLUMPK',
#   'modes': ['tube'],
#   'name': 'Moor Park',
#   'lat': 51.629845,
#   'lon': -0.432454,
#   'zone': '6+7',
#   'lines': ['metropolitan']},
#  'Moorgate Underground Station': {'ID': 'HUBZMG',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Moorgate',
#   'lat': 51.518338,
#   'lon': -0.088627,
#   'zone': '1',
#   'lines': ['circle', 'hammersmith-city', 'metropolitan', 'northern']},
#  'Morden Underground Station': {'ID': '940GZZLUMDN',
#   'modes': ['bus', 'tube'],
#   'name': 'Morden',
#   'lat': 51.402142,
#   'lon': -0.194839,
#   'zone': '4',
#   'lines': ['northern']},
#  'Mornington Crescent Underground Station': {'ID': '940GZZLUMTC',
#   'modes': ['tube', 'bus'],
#   'name': 'Mornington Crescent',
#   'lat': 51.534679,
#   'lon': -0.138789,
#   'zone': '2',
#   'lines': ['northern']},
#  'Neasden Underground Station': {'ID': '940GZZLUNDN',
#   'modes': ['tube', 'bus'],
#   'name': 'Neasden',
#   'lat': 51.553986,
#   'lon': -0.249837,
#   'zone': '3',
#   'lines': ['jubilee']},
#  'Newbury Park Underground Station': {'ID': '940GZZLUNBP',
#   'modes': ['tube', 'bus'],
#   'name': 'Newbury Park',
#   'lat': 51.575726,
#   'lon': 0.090004,
#   'zone': '4',
#   'lines': ['central']},
#  'North Acton Underground Station': {'ID': '940GZZLUNAN',
#   'modes': ['bus', 'tube'],
#   'name': 'North Acton',
#   'lat': 51.523524,
#   'lon': -0.259755,
#   'zone': '2+3',
#   'lines': ['central']},
#  'North Ealing Underground Station': {'ID': '940GZZLUNEN',
#   'modes': ['tube', 'bus'],
#   'name': 'North Ealing',
#   'lat': 51.517505,
#   'lon': -0.288868,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'North Harrow Underground Station': {'ID': '940GZZLUNHA',
#   'modes': ['tube', 'bus'],
#   'name': 'North Harrow',
#   'lat': 51.584872,
#   'lon': -0.362408,
#   'zone': '5',
#   'lines': ['metropolitan']},
#  'North Wembley Underground Station': {'ID': 'HUBNWB',
#   'modes': ['overground', 'tube', 'bus'],
#   'name': 'North Wembley',
#   'lat': 51.56258,
#   'lon': -0.303992,
#   'zone': '4',
#   'lines': ['bakerloo']},
#  'Northfields Underground Station': {'ID': '940GZZLUNFD',
#   'modes': ['bus', 'tube'],
#   'name': 'Northfields',
#   'lat': 51.499319,
#   'lon': -0.314719,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'Northolt Underground Station': {'ID': '940GZZLUNHT',
#   'modes': ['tube', 'bus'],
#   'name': 'Northolt',
#   'lat': 51.548236,
#   'lon': -0.368699,
#   'zone': '5',
#   'lines': ['central']},
#  'Northwick Park Underground Station': {'ID': '940GZZLUNKP',
#   'modes': ['tube', 'bus'],
#   'name': 'Northwick Park',
#   'lat': 51.578481,
#   'lon': -0.318056,
#   'zone': '4',
#   'lines': ['metropolitan']},
#  'Northwood Underground Station': {'ID': '940GZZLUNOW',
#   'modes': ['tube', 'bus'],
#   'name': 'Northwood',
#   'lat': 51.611053,
#   'lon': -0.423829,
#   'zone': '6',
#   'lines': ['metropolitan']},
#  'Northwood Hills Underground Station': {'ID': '940GZZLUNWH',
#   'modes': ['bus', 'tube'],
#   'name': 'Northwood Hills',
#   'lat': 51.600572,
#   'lon': -0.409464,
#   'zone': '6',
#   'lines': ['metropolitan']},
#  'Notting Hill Gate Underground Station': {'ID': '940GZZLUNHG',
#   'modes': ['tube', 'bus'],
#   'name': 'Notting Hill Gate',
#   'lat': 51.509128,
#   'lon': -0.196104,
#   'zone': '1+2',
#   'lines': ['central', 'circle', 'district']},
#  'Oakwood Underground Station': {'ID': '940GZZLUOAK',
#   'modes': ['bus', 'tube'],
#   'name': 'Oakwood',
#   'lat': 51.647726,
#   'lon': -0.132182,
#   'zone': '5',
#   'lines': ['piccadilly']},
#  'Old Street Underground Station': {'ID': 'HUBOLD',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Old Street',
#   'lat': 51.526065,
#   'lon': -0.088193,
#   'zone': '1',
#   'lines': ['northern']},
#  'Osterley Underground Station': {'ID': '940GZZLUOSY',
#   'modes': ['tube', 'bus'],
#   'name': 'Osterley',
#   'lat': 51.481274,
#   'lon': -0.352224,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Oval Underground Station': {'ID': '940GZZLUOVL',
#   'modes': ['tube', 'bus'],
#   'name': 'Oval',
#   'lat': 51.48185,
#   'lon': -0.112439,
#   'zone': '2',
#   'lines': ['northern']},
#  'Oxford Circus Underground Station': {'ID': '940GZZLUOXC',
#   'modes': ['tube', 'bus'],
#   'name': 'Oxford Circus',
#   'lat': 51.515224,
#   'lon': -0.141903,
#   'zone': '1',
#   'lines': ['bakerloo', 'central', 'victoria']},
#  'Paddington Underground Station': {'ID': 'HUBPAD',
#   'modes': ['bus', 'national-rail', 'tube', 'tflrail'],
#   'name': 'Paddington',
#   'lat': 51.516981,
#   'lon': -0.17616,
#   'zone': '1',
#   'lines': ['bakerloo', 'circle', 'district']},
#  'Park Royal Underground Station': {'ID': '940GZZLUPKR',
#   'modes': ['bus', 'tube'],
#   'name': 'Park Royal',
#   'lat': 51.527123,
#   'lon': -0.284341,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'Parsons Green Underground Station': {'ID': '940GZZLUPSG',
#   'modes': ['tube'],
#   'name': 'Parsons Green',
#   'lat': 51.475277,
#   'lon': -0.20117,
#   'zone': '2',
#   'lines': ['district']},
#  'Perivale Underground Station': {'ID': '940GZZLUPVL',
#   'modes': ['bus', 'tube'],
#   'name': 'Perivale',
#   'lat': 51.536717,
#   'lon': -0.323446,
#   'zone': '4',
#   'lines': ['central']},
#  'Piccadilly Circus Underground Station': {'ID': '940GZZLUPCC',
#   'modes': ['tube', 'bus'],
#   'name': 'Piccadilly Circus',
#   'lat': 51.51005,
#   'lon': -0.133798,
#   'zone': '1',
#   'lines': ['bakerloo', 'piccadilly']},
#  'Pimlico Underground Station': {'ID': '940GZZLUPCO',
#   'modes': ['bus', 'tube'],
#   'name': 'Pimlico',
#   'lat': 51.489097,
#   'lon': -0.133761,
#   'zone': '1',
#   'lines': ['victoria']},
#  'Pinner Underground Station': {'ID': '940GZZLUPNR',
#   'modes': ['bus', 'tube'],
#   'name': 'Pinner',
#   'lat': 51.592901,
#   'lon': -0.381161,
#   'zone': '5',
#   'lines': ['metropolitan']},
#  'Plaistow Underground Station': {'ID': '940GZZLUPLW',
#   'modes': ['tube', 'bus'],
#   'name': 'Plaistow',
#   'lat': 51.531341,
#   'lon': 0.017451,
#   'zone': '3',
#   'lines': ['district', 'hammersmith-city']},
#  'Preston Road Underground Station': {'ID': '940GZZLUPRD',
#   'modes': ['bus', 'tube'],
#   'name': 'Preston Road',
#   'lat': 51.571972,
#   'lon': -0.295107,
#   'zone': '4',
#   'lines': ['metropolitan']},
#  'Putney Bridge Underground Station': {'ID': '940GZZLUPYB',
#   'modes': ['bus', 'tube'],
#   'name': 'Putney Bridge',
#   'lat': 51.468262,
#   'lon': -0.208731,
#   'zone': '2',
#   'lines': ['district']},
#  "Queen's Park Underground Station": {'ID': 'HUBQPW',
#   'modes': ['overground', 'bus', 'national-rail', 'tube'],
#   'name': "Queen's Park",
#   'lat': 51.534443,
#   'lon': -0.204882,
#   'zone': '2',
#   'lines': ['bakerloo']},
#  'Queensbury Underground Station': {'ID': '940GZZLUQBY',
#   'modes': ['bus', 'tube'],
#   'name': 'Queensbury',
#   'lat': 51.594188,
#   'lon': -0.286219,
#   'zone': '4',
#   'lines': ['jubilee']},
#  'Queensway Underground Station': {'ID': '940GZZLUQWY',
#   'modes': ['tube', 'bus'],
#   'name': 'Queensway',
#   'lat': 51.510312,
#   'lon': -0.187152,
#   'zone': '1',
#   'lines': ['central']},
#  'Ravenscourt Park Underground Station': {'ID': '940GZZLURVP',
#   'modes': ['tube', 'bus'],
#   'name': 'Ravenscourt Park',
#   'lat': 51.494122,
#   'lon': -0.235881,
#   'zone': '2',
#   'lines': ['district']},
#  'Rayners Lane Underground Station': {'ID': '940GZZLURYL',
#   'modes': ['tube', 'bus'],
#   'name': 'Rayners Lane',
#   'lat': 51.575147,
#   'lon': -0.371127,
#   'zone': '5',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Redbridge Underground Station': {'ID': '940GZZLURBG',
#   'modes': ['bus', 'tube'],
#   'name': 'Redbridge',
#   'lat': 51.576243,
#   'lon': 0.04536,
#   'zone': '4',
#   'lines': ['central']},
#  "Regent's Park Underground Station": {'ID': '940GZZLURGP',
#   'modes': ['bus', 'tube'],
#   'name': "Regent's Park",
#   'lat': 51.523344,
#   'lon': -0.146444,
#   'zone': '1',
#   'lines': ['bakerloo']},
#  'Richmond Underground Station': {'ID': 'HUBRMD',
#   'modes': ['bus', 'overground', 'national-rail', 'tube'],
#   'name': 'Richmond',
#   'lat': 51.463152,
#   'lon': -0.301448,
#   'zone': '4',
#   'lines': ['district']},
#  'Rickmansworth Underground Station': {'ID': 'HUBRIC',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Rickmansworth',
#   'lat': 51.640247,
#   'lon': -0.473273,
#   'zone': '7',
#   'lines': ['metropolitan']},
#  'Roding Valley Underground Station': {'ID': '940GZZLURVY',
#   'modes': ['tube'],
#   'name': 'Roding Valley',
#   'lat': 51.617199,
#   'lon': 0.043647,
#   'zone': '4',
#   'lines': ['central']},
#  'Royal Oak Underground Station': {'ID': '940GZZLURYO',
#   'modes': ['bus', 'tube'],
#   'name': 'Royal Oak',
#   'lat': 51.519113,
#   'lon': -0.188748,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'South Ruislip Underground Station': {'ID': 'HUBSRU',
#   'modes': ['bus', 'tube', 'national-rail'],
#   'name': 'South Ruislip',
#   'lat': 51.556893,
#   'lon': -0.399076,
#   'zone': '5',
#   'lines': ['central']},
#  'Ruislip Gardens Underground Station': {'ID': '940GZZLURSG',
#   'modes': ['tube', 'bus'],
#   'name': 'Ruislip Gardens',
#   'lat': 51.560736,
#   'lon': -0.41071,
#   'zone': '5',
#   'lines': ['central']},
#  'Ruislip Manor Underground Station': {'ID': '940GZZLURSM',
#   'modes': ['tube', 'bus'],
#   'name': 'Ruislip Manor',
#   'lat': 51.573202,
#   'lon': -0.412973,
#   'zone': '6',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Russell Square Underground Station': {'ID': '940GZZLURSQ',
#   'modes': ['tube', 'bus'],
#   'name': 'Russell Square',
#   'lat': 51.523073,
#   'lon': -0.124285,
#   'zone': '1',
#   'lines': ['piccadilly']},
#  'Seven Sisters Underground Station': {'ID': 'HUBSVS',
#   'modes': ['overground', 'tube', 'national-rail', 'bus'],
#   'name': 'Seven Sisters',
#   'lat': 51.582931,
#   'lon': -0.073306,
#   'zone': '3',
#   'lines': ['victoria']},
#  "Shepherd's Bush Underground Station": {'ID': 'HUBSPB',
#   'modes': ['overground', 'bus', 'national-rail', 'tube'],
#   'name': "Shepherd's Bush",
#   'lat': 51.504791,
#   'lon': -0.219213,
#   'zone': '2',
#   'lines': []},
#  "Shepherd's Bush Market Underground Station": {'ID': '940GZZLUSBM',
#   'modes': ['tube'],
#   'name': "Shepherd's Bush Market",
#   'lat': 51.505579,
#   'lon': -0.226375,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Sloane Square Underground Station': {'ID': '940GZZLUSSQ',
#   'modes': ['bus', 'tube'],
#   'name': 'Sloane Square',
#   'lat': 51.49227,
#   'lon': -0.156377,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Snaresbrook Underground Station': {'ID': '940GZZLUSNB',
#   'modes': ['tube', 'bus'],
#   'name': 'Snaresbrook',
#   'lat': 51.580678,
#   'lon': 0.02144,
#   'zone': '4',
#   'lines': ['central']},
#  'South Ealing Underground Station': {'ID': '940GZZLUSEA',
#   'modes': ['tube', 'bus'],
#   'name': 'South Ealing',
#   'lat': 51.501003,
#   'lon': -0.307424,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'South Harrow Underground Station': {'ID': '940GZZLUSHH',
#   'modes': ['bus', 'tube'],
#   'name': 'South Harrow',
#   'lat': 51.564888,
#   'lon': -0.352492,
#   'zone': '5',
#   'lines': ['piccadilly']},
#  'South Kensington Underground Station': {'ID': '940GZZLUSKS',
#   'modes': ['tube', 'bus'],
#   'name': 'South Kensington',
#   'lat': 51.494094,
#   'lon': -0.174138,
#   'zone': '1',
#   'lines': ['circle', 'district', 'piccadilly']},
#  'South Kenton Underground Station': {'ID': 'HUBSOK',
#   'modes': ['bus', 'overground', 'tube'],
#   'name': 'South Kenton',
#   'lat': 51.570229,
#   'lon': -0.308448,
#   'zone': '4',
#   'lines': ['bakerloo']},
#  'South Wimbledon Underground Station': {'ID': '940GZZLUSWN',
#   'modes': ['bus', 'tube'],
#   'name': 'South Wimbledon',
#   'lat': 51.415309,
#   'lon': -0.192005,
#   'zone': '3+4',
#   'lines': ['northern']},
#  'South Woodford Underground Station': {'ID': '940GZZLUSWF',
#   'modes': ['tube', 'bus'],
#   'name': 'Woodford',
#   'lat': 51.591907,
#   'lon': 0.027338,
#   'zone': '4',
#   'lines': ['central']},
#  'Southfields Underground Station': {'ID': '940GZZLUSFS',
#   'modes': ['tube', 'bus'],
#   'name': 'Southfields',
#   'lat': 51.445073,
#   'lon': -0.206602,
#   'zone': '3',
#   'lines': ['district']},
#  'Southgate Underground Station': {'ID': '940GZZLUSGT',
#   'modes': ['bus', 'tube'],
#   'name': 'Southgate',
#   'lat': 51.632315,
#   'lon': -0.127816,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Southwark Underground Station': {'ID': '940GZZLUSWK',
#   'modes': ['tube', 'bus'],
#   'name': 'Southwark',
#   'lat': 51.50427,
#   'lon': -0.105331,
#   'zone': '1',
#   'lines': ['jubilee']},
#  "St. James's Park Underground Station": {'ID': '940GZZLUSJP',
#   'modes': ['bus', 'tube'],
#   'name': "St. James's Park",
#   'lat': 51.499544,
#   'lon': -0.133608,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  "St. John's Wood Underground Station": {'ID': '940GZZLUSJW',
#   'modes': ['tube', 'bus'],
#   'name': "St. John's Wood",
#   'lat': 51.534521,
#   'lon': -0.173948,
#   'zone': '2',
#   'lines': ['jubilee']},
#  "St. Paul's Underground Station": {'ID': '940GZZLUSPU',
#   'modes': ['bus', 'tube'],
#   'name': "St. Paul's",
#   'lat': 51.514936,
#   'lon': -0.097567,
#   'zone': '1',
#   'lines': ['central']},
#  'Stamford Brook Underground Station': {'ID': '940GZZLUSFB',
#   'modes': ['bus', 'tube'],
#   'name': 'Stamford Brook',
#   'lat': 51.494917,
#   'lon': -0.245704,
#   'zone': '2',
#   'lines': ['district']},
#  'Stanmore Underground Station': {'ID': '940GZZLUSTM',
#   'modes': ['bus', 'tube'],
#   'name': 'Stanmore',
#   'lat': 51.619839,
#   'lon': -0.303266,
#   'zone': '5',
#   'lines': ['jubilee']},
#  'Stepney Green Underground Station': {'ID': '940GZZLUSGN',
#   'modes': ['tube', 'bus'],
#   'name': 'Stepney Green',
#   'lat': 51.521858,
#   'lon': -0.046596,
#   'zone': '2',
#   'lines': ['district', 'hammersmith-city']},
#  'Stockwell Underground Station': {'ID': '940GZZLUSKW',
#   'modes': ['bus', 'tube'],
#   'name': 'Stockwell',
#   'lat': 51.472184,
#   'lon': -0.122644,
#   'zone': '2',
#   'lines': ['northern', 'victoria']},
#  'Stonebridge Park Underground Station': {'ID': 'HUBSBP',
#   'modes': ['overground', 'tube', 'bus'],
#   'name': 'Stonebridge Park',
#   'lat': 51.544041,
#   'lon': -0.275859,
#   'zone': '3',
#   'lines': ['bakerloo']},
#  'Stratford Underground Station': {'ID': 'HUBSRA',
#   'modes': ['international-rail',
#    'tube',
#    'national-rail',
#    'dlr',
#    'bus',
#    'tflrail',
#    'overground'],
#   'name': 'Stratford',
#   'lat': 51.541508,
#   'lon': -0.00241,
#   'zone': '2/3',
#   'lines': ['central', 'jubilee']},
#  'Sudbury Town Underground Station': {'ID': '940GZZLUSUT',
#   'modes': ['bus', 'tube'],
#   'name': 'Sudbury Town',
#   'lat': 51.550815,
#   'lon': -0.315745,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Swiss Cottage Underground Station': {'ID': '940GZZLUSWC',
#   'modes': ['bus', 'tube'],
#   'name': 'Swiss Cottage',
#   'lat': 51.543681,
#   'lon': -0.174894,
#   'zone': '2',
#   'lines': ['jubilee']},
#  'Temple Underground Station': {'ID': '940GZZLUTMP',
#   'modes': ['tube'],
#   'name': 'Temple',
#   'lat': 51.511006,
#   'lon': -0.11426,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Theydon Bois Underground Station': {'ID': '940GZZLUTHB',
#   'modes': ['tube'],
#   'name': 'Theydon Bois',
#   'lat': 51.671759,
#   'lon': 0.103085,
#   'zone': '6',
#   'lines': ['central']},
#  'Tooting Bec Underground Station': {'ID': '940GZZLUTBC',
#   'modes': ['tube', 'bus'],
#   'name': 'Tooting Bec',
#   'lat': 51.435678,
#   'lon': -0.159736,
#   'zone': '3',
#   'lines': ['northern']},
#  'Tooting Broadway Underground Station': {'ID': '940GZZLUTBY',
#   'modes': ['bus', 'tube'],
#   'name': 'Tooting Broadway',
#   'lat': 51.42763,
#   'lon': -0.168374,
#   'zone': '3',
#   'lines': ['northern']},
#  'Tottenham Court Road Underground Station': {'ID': '940GZZLUTCR',
#   'modes': ['bus', 'tube'],
#   'name': 'Tottenham Court Road',
#   'lat': 51.516426,
#   'lon': -0.13041,
#   'zone': '1',
#   'lines': ['central', 'northern']},
#  'Tottenham Hale Underground Station': {'ID': 'HUBTOM',
#   'modes': ['tube', 'national-rail', 'bus'],
#   'name': 'Tottenham Hale',
#   'lat': 51.588315,
#   'lon': -0.06024,
#   'zone': '3',
#   'lines': ['victoria']},
#  'Totteridge & Whetstone Underground Station': {'ID': '940GZZLUTAW',
#   'modes': ['bus', 'tube'],
#   'name': 'Totteridge & Whetstone',
#   'lat': 51.630597,
#   'lon': -0.17921,
#   'zone': '4',
#   'lines': ['northern']},
#  'Tower Hill Underground Station': {'ID': '940GZZLUTWH',
#   'modes': ['tube'],
#   'name': 'Tower Hill',
#   'lat': 51.509971,
#   'lon': -0.076546,
#   'zone': '1',
#   'lines': ['circle', 'district']},
#  'Tufnell Park Underground Station': {'ID': '940GZZLUTFP',
#   'modes': ['bus', 'tube'],
#   'name': 'Tufnell Park',
#   'lat': 51.556822,
#   'lon': -0.138433,
#   'zone': '2',
#   'lines': ['northern']},
#  'Turnham Green Underground Station': {'ID': '940GZZLUTNG',
#   'modes': ['bus', 'tube'],
#   'name': 'Turnham Green',
#   'lat': 51.495148,
#   'lon': -0.254555,
#   'zone': '2',
#   'lines': ['district', 'piccadilly']},
#  'Turnpike Lane Underground Station': {'ID': '940GZZLUTPN',
#   'modes': ['bus', 'tube'],
#   'name': 'Turnpike Lane',
#   'lat': 51.590272,
#   'lon': -0.102953,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'Upminster Underground Station': {'ID': 'HUBUPM',
#   'modes': ['national-rail', 'overground', 'bus', 'tube'],
#   'name': 'Upminster',
#   'lat': 51.558659,
#   'lon': 0.250855,
#   'zone': '6',
#   'lines': ['district']},
#  'Upminster Bridge Underground Station': {'ID': '940GZZLUUPB',
#   'modes': ['bus', 'tube'],
#   'name': 'Upminster Bridge',
#   'lat': 51.55856,
#   'lon': 0.235809,
#   'zone': '6',
#   'lines': ['district']},
#  'Upney Underground Station': {'ID': '940GZZLUUPY',
#   'modes': ['bus', 'tube'],
#   'name': 'Upney',
#   'lat': 51.538372,
#   'lon': 0.10153,
#   'zone': '4',
#   'lines': ['district']},
#  'Upton Park Underground Station': {'ID': '940GZZLUUPK',
#   'modes': ['bus', 'tube'],
#   'name': 'Upton Park',
#   'lat': 51.53534,
#   'lon': 0.035263,
#   'zone': '3',
#   'lines': ['district', 'hammersmith-city']},
#  'Uxbridge Underground Station': {'ID': '940GZZLUUXB',
#   'modes': ['bus', 'tube'],
#   'name': 'Uxbridge',
#   'lat': 51.546565,
#   'lon': -0.477949,
#   'zone': '6',
#   'lines': ['metropolitan', 'piccadilly']},
#  'Vauxhall Underground Station': {'ID': 'HUBVXH',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Vauxhall',
#   'lat': 51.485739,
#   'lon': -0.123303,
#   'zone': '1+2',
#   'lines': ['victoria']},
#  'Victoria Underground Station': {'ID': 'HUBVIC',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Victoria',
#   'lat': 51.495812,
#   'lon': -0.143826,
#   'zone': '1',
#   'lines': ['circle', 'district', 'victoria']},
#  'Walthamstow Central Underground Station': {'ID': 'HUBWHC',
#   'modes': ['national-rail', 'bus', 'overground', 'tube'],
#   'name': 'Walthamstow Central',
#   'lat': 51.582948,
#   'lon': -0.019842,
#   'zone': '3',
#   'lines': ['victoria']},
#  'Warren Street Underground Station': {'ID': '940GZZLUWRR',
#   'modes': ['bus', 'tube'],
#   'name': 'Warren Street',
#   'lat': 51.524951,
#   'lon': -0.138321,
#   'zone': '1',
#   'lines': ['northern', 'victoria']},
#  'Warwick Avenue Underground Station': {'ID': '940GZZLUWKA',
#   'modes': ['bus', 'tube'],
#   'name': 'Warwick Avenue',
#   'lat': 51.523263,
#   'lon': -0.183783,
#   'zone': '2',
#   'lines': ['bakerloo']},
#  'Waterloo Underground Station': {'ID': 'HUBWAT',
#   'modes': ['bus', 'national-rail', 'tube'],
#   'name': 'Waterloo',
#   'lat': 51.504269,
#   'lon': -0.113356,
#   'zone': '1',
#   'lines': ['bakerloo', 'jubilee', 'northern', 'waterloo-city']},
#  'Wembley Central Underground Station': {'ID': 'HUBWMB',
#   'modes': ['bus', 'national-rail', 'overground', 'tube'],
#   'name': 'Wembley Central',
#   'lat': 51.55232,
#   'lon': -0.296642,
#   'zone': '4',
#   'lines': ['bakerloo']},
#  'Wembley Park Underground Station': {'ID': '940GZZLUWYP',
#   'modes': ['bus', 'tube'],
#   'name': 'Wembley Park',
#   'lat': 51.563198,
#   'lon': -0.279262,
#   'zone': '4',
#   'lines': ['jubilee', 'metropolitan']},
#  'West Acton Underground Station': {'ID': '940GZZLUWTA',
#   'modes': ['tube', 'bus'],
#   'name': 'West Acton',
#   'lat': 51.518001,
#   'lon': -0.28098,
#   'zone': '3',
#   'lines': ['central']},
#  'West Brompton Underground Station': {'ID': 'HUBWBP',
#   'modes': ['national-rail', 'overground', 'tube', 'bus'],
#   'name': 'West Brompton',
#   'lat': 51.487168,
#   'lon': -0.195593,
#   'zone': '2',
#   'lines': ['district']},
#  'West Finchley Underground Station': {'ID': '940GZZLUWFN',
#   'modes': ['tube'],
#   'name': 'West Finchley',
#   'lat': 51.609426,
#   'lon': -0.188362,
#   'zone': '4',
#   'lines': ['northern']},
#  'West Ham Underground Station': {'ID': 'HUBWEH',
#   'modes': ['national-rail', 'tube', 'dlr', 'bus'],
#   'name': 'West Ham',
#   'lat': 51.528178,
#   'lon': 0.004997,
#   'zone': '2/3',
#   'lines': ['district', 'hammersmith-city', 'jubilee']},
#  'West Harrow Underground Station': {'ID': '940GZZLUWHW',
#   'modes': ['tube'],
#   'name': 'West Harrow',
#   'lat': 51.57971,
#   'lon': -0.3534,
#   'zone': '5',
#   'lines': ['metropolitan']},
#  'West Kensington Underground Station': {'ID': '940GZZLUWKN',
#   'modes': ['bus', 'tube'],
#   'name': 'West Kensington',
#   'lat': 51.490459,
#   'lon': -0.206636,
#   'zone': '2',
#   'lines': ['district']},
#  'West Ruislip Underground Station': {'ID': 'HUBWRU',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'West Ruislip',
#   'lat': 51.569721,
#   'lon': -0.437816,
#   'zone': '6',
#   'lines': ['central']},
#  'Westbourne Park Underground Station': {'ID': '940GZZLUWSP',
#   'modes': ['bus', 'tube'],
#   'name': 'Westbourne Park',
#   'lat': 51.52111,
#   'lon': -0.201065,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Westminster Underground Station': {'ID': 'HUBWSM',
#   'modes': ['tube', 'bus'],
#   'name': 'Westminster',
#   'lat': 51.501603,
#   'lon': -0.125984,
#   'zone': '1',
#   'lines': ['circle', 'district', 'jubilee']},
#  'White City Underground Station': {'ID': '940GZZLUWCY',
#   'modes': ['tube', 'bus'],
#   'name': 'White City',
#   'lat': 51.511959,
#   'lon': -0.224297,
#   'zone': '2',
#   'lines': ['central']},
#  'Whitechapel Underground Station': {'ID': 'HUBZWL',
#   'modes': ['bus', 'tube', 'overground'],
#   'name': 'Whitechapel',
#   'lat': 51.519498,
#   'lon': -0.059858,
#   'zone': '2',
#   'lines': ['district', 'hammersmith-city']},
#  'Willesden Green Underground Station': {'ID': '940GZZLUWIG',
#   'modes': ['bus', 'tube'],
#   'name': 'Willesden Green',
#   'lat': 51.549146,
#   'lon': -0.221537,
#   'zone': '2+3',
#   'lines': ['jubilee', 'metropolitan']},
#  'Willesden Junction Underground Station': {'ID': 'HUBWIJ',
#   'modes': ['bus', 'overground', 'tube'],
#   'name': 'Willesden Junction',
#   'lat': 51.532556,
#   'lon': -0.243006,
#   'zone': '2+3',
#   'lines': ['bakerloo']},
#  'Wimbledon Underground Station': {'ID': 'HUBWIM',
#   'modes': ['national-rail', 'tube', 'tram', 'bus'],
#   'name': 'Wimbledon',
#   'lat': 51.421505,
#   'lon': -0.206444,
#   'zone': '3',
#   'lines': ['district']},
#  'Wimbledon Park Underground Station': {'ID': '940GZZLUWIP',
#   'modes': ['tube'],
#   'name': 'Wimbledon Park',
#   'lat': 51.434573,
#   'lon': -0.199719,
#   'zone': '3',
#   'lines': ['district']},
#  'Wood Green Underground Station': {'ID': '940GZZLUWOG',
#   'modes': ['bus', 'tube'],
#   'name': 'Wood Green',
#   'lat': 51.597479,
#   'lon': -0.109886,
#   'zone': '3',
#   'lines': ['piccadilly']},
#  'Wood Lane Underground Station': {'ID': '940GZZLUWLA',
#   'modes': ['tube'],
#   'name': 'Wood Lane',
#   'lat': 51.509669,
#   'lon': -0.22453,
#   'zone': '2',
#   'lines': ['circle', 'hammersmith-city']},
#  'Woodside Park Underground Station': {'ID': '940GZZLUWOP',
#   'modes': ['tube', 'bus'],
#   'name': 'Woodside Park',
#   'lat': 51.618014,
#   'lon': -0.18542,
#   'zone': '4',
#   'lines': ['northern']},
#  "King's Cross St. Pancras Underground Station": {'ID': 'HUBKGX',
#   'modes': ['international-rail', 'national-rail', 'tube', 'bus'],
#   'name': "King's Cross St. Pancras",
#   'lat': 51.531683,
#   'lon': -0.123538,
#   'zone': '1',
#   'lines': ['circle',
#    'hammersmith-city',
#    'metropolitan',
#    'northern',
#    'piccadilly',
#    'victoria']}}

# %%
picStops = []
for i in stops:
    if ('piccadilly' in stops[i]['lines']):
        print(i, ';', stops[i]['lon'], ';',  stops[i]['lat'] )
        
picStops
# Out:
# Acton Town Underground Station ; -0.280462 ; 51.503057
# Alperton Underground Station ; -0.29961 ; 51.540627
# Arnos Grove Underground Station ; -0.133062 ; 51.616446
# Barons Court Underground Station ; -0.213427 ; 51.490311
# Boston Manor Underground Station ; -0.324939 ; 51.495635
# Bounds Green Underground Station ; -0.124235 ; 51.607034
# Cockfosters Underground Station ; -0.149171 ; 51.65152
# Covent Garden Underground Station ; -0.124436 ; 51.513093
# Ealing Common Underground Station ; -0.288265 ; 51.51014
# Earl's Court Underground Station ; -0.193378 ; 51.492063
# Eastcote Underground Station ; -0.397373 ; 51.576506
# Finsbury Park Underground Station ; -0.105876 ; 51.564778
# Gloucester Road Underground Station ; -0.182658 ; 51.494316
# Green Park Underground Station ; -0.142787 ; 51.506947
# Hatton Cross Underground Station ; -0.423191 ; 51.466747
# Hillingdon Underground Station ; -0.449828 ; 51.553715
# Holborn Underground Station ; -0.120475 ; 51.51758
# Holloway Road Underground Station ; -0.113244 ; 51.552697
# Hounslow Central Underground Station ; -0.366578 ; 51.471295
# Hounslow East Underground Station ; -0.356474 ; 51.473213
# Hounslow West Underground Station ; -0.386544 ; 51.473469
# Hyde Park Corner Underground Station ; -0.152441 ; 51.503035
# Ickenham Underground Station ; -0.442001 ; 51.561992
# Knightsbridge Underground Station ; -0.160508 ; 51.501669
# Leicester Square Underground Station ; -0.128426 ; 51.511386
# Manor House Underground Station ; -0.096118 ; 51.570738
# North Ealing Underground Station ; -0.288868 ; 51.517505
# Northfields Underground Station ; -0.314719 ; 51.499319
# Oakwood Underground Station ; -0.132182 ; 51.647726
# Osterley Underground Station ; -0.352224 ; 51.481274
# Park Royal Underground Station ; -0.284341 ; 51.527123
# Piccadilly Circus Underground Station ; -0.133798 ; 51.51005
# Rayners Lane Underground Station ; -0.371127 ; 51.575147
# Ruislip Manor Underground Station ; -0.412973 ; 51.573202
# Russell Square Underground Station ; -0.124285 ; 51.523073
# South Ealing Underground Station ; -0.307424 ; 51.501003
# South Harrow Underground Station ; -0.352492 ; 51.564888
# South Kensington Underground Station ; -0.174138 ; 51.494094
# Southgate Underground Station ; -0.127816 ; 51.632315
# Sudbury Town Underground Station ; -0.315745 ; 51.550815
# Turnham Green Underground Station ; -0.254555 ; 51.495148
# Turnpike Lane Underground Station ; -0.102953 ; 51.590272
# Uxbridge Underground Station ; -0.477949 ; 51.546565
# Wood Green Underground Station ; -0.109886 ; 51.597479
# King's Cross St. Pancras Underground Station ; -0.123538 ; 51.531683
# []
