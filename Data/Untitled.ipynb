# %%
import json
import urllib
import pprint
import numpy as np

# %%
geoJson = 'https://raw.githubusercontent.com/oobrien/vis/master/tube/data/tfl_lines.json'
response = urllib.request.urlopen(str(geoJson))
search = json.loads(response.read())
search = search['features']

# %%
#Piccadilly line
pic = []

for i in range(106, 111):
    for j in search[i]['geometry']['coordinates']:
        print(i, j[0], j[1])
        pic.append(j)
        
        
#pic
# Out:
# 106 -0.18835498901684 51.49713766425822
# 106 -0.189274229263027 51.4980913
# 106 -0.189790258526055 51.4984603
# 106 -0.190237501936477 51.4987422
# 106 -0.190473158526055 51.498907807008486
# 106 -0.190610041473945 51.499004352900634
# 106 -0.190807327326551 51.49915435111334
# 106 -0.1909675 51.4992622
# 106 -0.1917412 51.5000091
# 106 -0.1921995 51.5004558
# 106 -0.1923042 51.5005537
# 106 -0.192646625881619 51.500926538073465
# 107 -0.192672473624642 51.50095656242031
# 107 -0.193223 51.501639
# 107 -0.1934199 51.5020038
# 107 -0.1936652 51.5024602
# 107 -0.1939675 51.5031803
# 107 -0.1942948 51.5039943
# 107 -0.1943242 51.5040691
# 107 -0.195196 51.5063828
# 107 -0.1953392 51.5067578
# 107 -0.1957236 51.5078135
# 107 -0.1958171 51.5080901
# 107 -0.1959239 51.5084386
# 107 -0.1959923 51.5086212
# 107 -0.1960391 51.508721
# 107 -0.1960681 51.5088132
# 107 -0.1960842 51.5089394
# 107 -0.1960883 51.5090662
# 107 -0.196093735982895 51.50917992881233
# ...

# %%
url = 'https://raw.githubusercontent.com/domherriott/london_map/master/Data/dStops.json'
response = urllib.request.urlopen(url)
stops = json.loads(response.read())
stops
# Out:
# {'Acton Town Underground Station': {'ID': '940GZZLUACT',
#   'modes': ['tube', 'bus'],
#   'name': 'Acton Town',
#   'lat': 51.503057,
#   'lon': -0.280462,
#   'zone': '3',
#   'lines': ['district', 'piccadilly']},
#  'Aldgate East Underground Station': {'ID': '940GZZLUADE',
#   'modes': ['tube', 'bus'],
#   'name': 'Aldgate East',
#   'lat': 51.515037,
#   'lon': -0.072384,
#   'zone': '1',
#   'lines': ['district', 'hammersmith-city']},
#  'Alperton Underground Station': {'ID': '940GZZLUALP',
#   'modes': ['bus', 'tube'],
#   'name': 'Alperton',
#   'lat': 51.540627,
#   'lon': -0.29961,
#   'zone': '4',
#   'lines': ['piccadilly']},
#  'Amersham Underground Station': {'ID': 'HUBAMR',
#   'modes': ['national-rail', 'tube', 'bus'],
#   'name': 'Amersham',
#   'lat': 51.674207,
#   'lon': -0.60759,
#   'zone': '9',
#   'lines': ['metropolitan']},
#  'Angel Underground Station': {'ID': '940GZZLUAGL',
#   'modes': ['bus', 'tube'],
#   'name': 'Angel',
#   'lat': 51.532796,
# ...

# %%
picStops = []
for i in stops:
    if ('district' in stops[i]['lines']):
        print(i, ';', stops[i]['lon'], ';',  stops[i]['lat'] )
        
picStops
# Out:
# Acton Town Underground Station ; -0.280462 ; 51.503057
# Aldgate East Underground Station ; -0.072384 ; 51.515037
# Barking Underground Station ; 0.080988 ; 51.539413
# Barons Court Underground Station ; -0.213427 ; 51.490311
# Bayswater Underground Station ; -0.187938 ; 51.512284
# Becontree Underground Station ; 0.127016 ; 51.540331
# Blackfriars Underground Station ; -0.104166 ; 51.509613
# Bow Road Underground Station ; -0.025128 ; 51.52694
# Bromley-by-Bow Underground Station ; -0.011538 ; 51.524839
# Cannon Street Underground Station ; -0.090357 ; 51.511451
# Chiswick Park Underground Station ; -0.267972 ; 51.494627
# Dagenham East Underground Station ; 0.166017 ; 51.544096
# Dagenham Heathway Underground Station ; 0.147527 ; 51.541639
# Ealing Broadway Underground Station ; -0.302131 ; 51.514993
# Ealing Common Underground Station ; -0.288265 ; 51.51014
# Earl's Court Underground Station ; -0.193378 ; 51.492063
# East Ham Underground Station ; 0.051186 ; 51.538948
# ...
